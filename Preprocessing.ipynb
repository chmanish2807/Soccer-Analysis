# %% [markdown]
# # This are the steps we have done in this File
# ###      In appearances, game_events, player_valuations have changed the date format to pandas datetime format.
# ###      In club_games dropped the own_position, own_manager_name, opponent_position, opponent_manager_name columns from the dataset
# ###      In clubs dropped  total_market_value, coach_name, filename, url column fromthe dataset.
# ###      In competiotions removed the last 2 columns from the dataset

# %% [markdown]
# # Data Cleaning Summary:
#
# ####     Appearances, Game Events, Player Valuations: Converted the "date" column to pandas datetime format for improved date and time handling.
# ####     Club Games: Removed the following columns as they were deemed unnecessary for further analysis:
# ####         own_position
# ####         own_manager_name
# ####         opponent_position
# ####         opponent_manager_name
# ####
# ####

# %%
import pandas as pd

# %%
df1=pd.read_csv('/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/appearances.csv')
df2=pd.read_csv('/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/club_games.csv')
df3=pd.read_csv('/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/clubs.csv')
df4=pd.read_csv('/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/competitions.csv')
df5=pd.read_csv('/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/game_events.csv')
df6=pd.read_csv('/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/game_lineups.csv')
df7=pd.read_csv('/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/games.csv')
df8=pd.read_csv('/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/player_valuations.csv')
df9=pd.read_csv('/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/players.csv')
# Out:
# /var/folders/08/118k91t13wq08mnszr49vpmr0000gn/T/ipykernel_18285/2256369382.py:6: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df6=pd.read_csv('/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/game_lineups.csv')

# %%
csv_filenames = ["/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/appearances.csv",
                  "/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/club_games.csv",
                  '/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/clubs.csv',
                  '/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/competitions.csv',
                  '/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/game_events.csv',
                  '/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/game_lineups.csv',
                  '/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/games.csv',
                  '/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/player_valuations.csv',
                  '/Users/manishchetlapally/Documents/Spring 2024/DMQL/Project/Football_Dataset/players.csv'] 

dataframes = []
for filename in csv_filenames:
    try:
        dataframes.append(pd.read_csv(filename))
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except pd.errors.ParserError as e:
        print(f"Error parsing '{filename}': {e}")  # Handle CSV parsing errors

if not dataframes:
    raise ValueError("No valid CSV files found!")
# Out:
# /var/folders/08/118k91t13wq08mnszr49vpmr0000gn/T/ipykernel_26099/2216924312.py:14: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframes.append(pd.read_csv(filename))

# %%
dataframes[0].columns
# Out:
# Index(['appearance_id', 'game_id', 'player_id', 'player_club_id',
#        'player_current_club_id', 'date', 'player_name', 'competition_id',
#        'yellow_cards', 'red_cards', 'goals', 'assists', 'minutes_played'],
#       dtype='object')

# %%
for i in (dataframes):
    print(i.shape)
# Out:
# (1533342, 13)
# (133090, 11)
# (426, 17)
# (43, 10)
# (687445, 10)
# (2318953, 9)
# (66545, 23)
# (465254, 5)
# (30484, 23)

# %%
for null_values in dataframes:
    print(null_values.isnull().sum())
# Out:
# appearance_id             0
# game_id                   0
# player_id                 0
# player_club_id            0
# player_current_club_id    0
# date                      0
# player_name               1
# competition_id            0
# yellow_cards              0
# red_cards                 0
# goals                     0
# assists                   0
# minutes_played            0
# dtype: int64
# game_id                      0
# club_id                      0
# own_goals                    0
# own_position             39562
# own_manager_name          1486
# opponent_id                  0
# opponent_goals               0
# opponent_position        39562
# opponent_manager_name     1486
# hosting                      0
# is_win                       0
# dtype: int64
# club_id                      0
# club_code                    0
# name                         0
# domestic_competition_id      0
# total_market_value         426
# squad_size                   0
# ...

# %%
for i in dataframes:
    print(i.isnull().sum())
# Out:
# appearance_id             0
# game_id                   0
# player_id                 0
# player_club_id            0
# player_current_club_id    0
# date                      0
# player_name               1
# competition_id            0
# yellow_cards              0
# red_cards                 0
# goals                     0
# assists                   0
# minutes_played            0
# dtype: int64
# game_id                      0
# club_id                      0
# own_goals                    0
# own_position             39562
# own_manager_name          1486
# opponent_id                  0
# opponent_goals               0
# opponent_position        39562
# opponent_manager_name     1486
# hosting                      0
# is_win                       0
# dtype: int64
# club_id                      0
# club_code                    0
# name                         0
# domestic_competition_id      0
# total_market_value         426
# squad_size                   0
# ...

# %%
df1.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date       player_name competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim            CLQ             0          0
# 1  2012-07-05    Ruslan Abyshov            ELQ             0          0
# 2  2012-07-05       Sander Puri            ELQ             0          0
# 3  2012-07-05   Vegar Hedenstad            ELQ             0          0
# 4  2012-07-05  Markus Henriksen            ELQ             0          0
#
#    goals  assists  minutes_played
# ...

# %%
df1.shape
# Out:
# (1533342, 13)

# %%
df1.columns
# Out:
# Index(['appearance_id', 'game_id', 'player_id', 'player_club_id',
#        'player_current_club_id', 'date', 'player_name', 'competition_id',
#        'yellow_cards', 'red_cards', 'goals', 'assists', 'minutes_played'],
#       dtype='object')

# %%
df1['date'] = pd.to_datetime(df1['date'])

# %%
df_filtered = df1[df1['date'] >= pd.to_datetime('2019-02-24')]
print(df_filtered)
# Out:
#           appearance_id  game_id  player_id  player_club_id  \
# 871717   3047774_131996  3047774     131996            1041
# 871718   3047774_137745  3047774     137745            1041
# 871719   3047774_161869  3047774     161869             162
# 871720   3047774_167850  3047774     167850            1041
# 871721   3047774_174694  3047774     174694             162
# ...                 ...      ...        ...             ...
# 1533337  4129660_662140  4129660     662140            3205
# 1533338   4129660_77710  4129660      77710             114
# 1533339  4129660_873445  4129660     873445             114
# 1533340  4129660_875334  4129660     875334             114
# 1533341  4129660_889613  4129660     889613            3205
#
#          player_current_club_id       date      player_name competition_id  \
# 871717                     1050 2019-02-24  Bertrand Traoré            FR1
# 871718                      543 2019-02-24           Marçal            FR1
# ...

# %%
df1['date'].head
# Out:
# <bound method NDFrame.head of 0         2012-07-03
# 1         2012-07-05
# 2         2012-07-05
# 3         2012-07-05
# 4         2012-07-05
#              ...
# 1533337   2024-02-12
# 1533338   2024-02-12
# 1533339   2024-02-12
# 1533340   2024-02-12
# 1533341   2024-02-12
# Name: date, Length: 1533342, dtype: datetime64[ns]>

# %%
df_filtered.head()
# Out:
#          appearance_id  game_id  player_id  player_club_id  \
# 871717  3047774_131996  3047774     131996            1041
# 871718  3047774_137745  3047774     137745            1041
# 871719  3047774_161869  3047774     161869             162
# 871720  3047774_167850  3047774     167850            1041
# 871721  3047774_174694  3047774     174694             162
#
#         player_current_club_id       date      player_name competition_id  \
# 871717                    1050 2019-02-24  Bertrand Traoré            FR1
# 871718                     543 2019-02-24           Marçal            FR1
# 871719                    2441 2019-02-24   Djibril Sidibé            FR1
# 871720                      13 2019-02-24    Memphis Depay            FR1
# 871721                    1075 2019-02-24       Rony Lopes            FR1
#
#         yellow_cards  red_cards  goals  assists  minutes_played
# 871717             0          0      0        0              90
# ...

# %%
df_filtered.shape
# Out:
# (661625, 13)

# %%
# import os
# desktop_path = os.path.expanduser('~') + '/Desktop'
# df_filtered.to_csv(os.path.join(desktop_path, 'appearance.csv'), index=False)

# %%
df2.head()
# Out:
#    game_id  club_id  own_goals  own_position      own_manager_name  \
# 0  2320450     1468          0           NaN     Holger Bachthaler
# 1  2320460        1          3           NaN       Jürgen Luginger
# 2  2320472     2036          4           NaN         Frank Schmidt
# 3  2321044       16          2           1.0          Jürgen Klopp
# 4  2321060       23          0          18.0  Torsten Lieberknecht
#
#    opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 0           24               2                NaN             Armin Veh
# 1           86               1                NaN            Robin Dutt
# 2           72               5                NaN     Alexander Schmidt
# 3           23               1               15.0  Torsten Lieberknecht
# 4           24               2               11.0             Armin Veh
#
#   hosting  is_win
# 0    Home       0
# 1    Home       1
# 2    Home       0
# 3    Home       1
# 4    Home       0

# %%
df2.isnull().sum()
# Out:
# game_id                      0
# club_id                      0
# own_goals                    0
# own_position             39562
# own_manager_name          1486
# opponent_id                  0
# opponent_goals               0
# opponent_position        39562
# opponent_manager_name     1486
# hosting                      0
# is_win                       0
# dtype: int64

# %%
df2['own_position'].fillna(0,inplace=True)
df2['own_manager_name'].fillna(0,inplace=True)
df2['opponent_position'].fillna(0,inplace=True)
df2['opponent_manager_name'].fillna(0,inplace=True)
df2.isnull().sum()
# Out:
# game_id                  0
# club_id                  0
# own_goals                0
# own_position             0
# own_manager_name         0
# opponent_id              0
# opponent_goals           0
# opponent_position        0
# opponent_manager_name    0
# hosting                  0
# is_win                   0
# dtype: int64

# %%
df2.shape
# Out:
# (133090, 11)

# %%
df3.shape
# Out:
# (426, 17)

# %%
df3.head()
# Out:
#    club_id          club_code                              name  \
# 0      105    sv-darmstadt-98  Sportverein Darmstadt 1898 e. V.
# 1    11127  ural-ekaterinburg             FK Ural Yekaterinburg
# 2      114  besiktas-istanbul         Beşiktaş Jimnastik Kulübü
# 3       12             as-rom        Associazione Sportiva Roma
# 4      148  tottenham-hotspur   Tottenham Hotspur Football Club
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                      L1                 NaN          31         26.5
# 1                     RU1                 NaN          26         27.5
# 2                     TR1                 NaN          37         26.2
# 3                     IT1                 NaN          27         26.5
# 4                     GB1                 NaN          26         25.4
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# 0                 11                   35.5                      1
# ...

# %%
df_filtered_3 = df3.drop(columns=['total_market_value','coach_name','filename','url'],axis=1)
df_filtered_3.head()
# Out:
#    club_id          club_code                              name  \
# 0      105    sv-darmstadt-98  Sportverein Darmstadt 1898 e. V.
# 1    11127  ural-ekaterinburg             FK Ural Yekaterinburg
# 2      114  besiktas-istanbul         Beşiktaş Jimnastik Kulübü
# 3       12             as-rom        Associazione Sportiva Roma
# 4      148  tottenham-hotspur   Tottenham Hotspur Football Club
#
#   domestic_competition_id  squad_size  average_age  foreigners_number  \
# 0                      L1          31         26.5                 11
# 1                     RU1          26         27.5                 15
# 2                     TR1          37         26.2                 17
# 3                     IT1          27         26.5                 18
# 4                     GB1          26         25.4                 20
#
#    foreigners_percentage  national_team_players  \
# 0                   35.5                      1
# 1                   57.7                      6
# ...

# %%
df_filtered_3.shape
# Out:
# (426, 13)

# %%
# import os
# desktop_path = os.path.expanduser('~') + '/Desktop'
# df_filtered_3.to_csv(os.path.join(desktop_path, 'clubs.csv'), index=False)

# %%
df_filtered_4 = df4.drop(df4.columns[-2:], axis=1)
df_filtered_4.head()
# Out:
#   competition_id               competition_code  \
# 0            CIT                      italy-cup
# 1           NLSC           johan-cruijff-schaal
# 2            GRP                kypello-elladas
# 3           POSU  supertaca-candido-de-oliveira
# 4           RUSS              russian-super-cup
#
#                             name            sub_type          type  \
# 0                      italy-cup        domestic_cup  domestic_cup
# 1           johan-cruijff-schaal  domestic_super_cup         other
# 2                kypello-elladas        domestic_cup  domestic_cup
# 3  supertaca-candido-de-oliveira  domestic_super_cup         other
# 4              russian-super-cup  domestic_super_cup         other
#
#    country_id country_name domestic_league_code
# 0          75        Italy                  IT1
# 1         122  Netherlands                  NL1
# 2          56       Greece                  GR1
# 3         136     Portugal                  PO1
# ...

# %%
df_filtered_4['country_id'].isnull().sum()
# Out:
# 0

# %%
# import os
# desktop_path = os.path.expanduser('~') + '/Desktop'
# df_filtered_4.to_csv(os.path.join(desktop_path, 'competitions.csv'), index=False)

# %%
df5.shape
# Out:
# (687445, 10)

# %%
df5.head()
# Out:
#                       game_event_id        date  game_id  minute  \
# 0  2f41da30c471492e7d4a984951671677  2012-08-05  2211607      77
# 1  a72f7186d132775f234d3e2f7bc0ed5b  2012-08-05  2211607      77
# 2  b2d721eaed4692a5c59a92323689ef18  2012-08-05  2211607       3
# 3  aef768899cedac0c9a650980219075a2  2012-08-05  2211607      53
# 4  5d6d9533023057b6619ecd145a038bbe  2012-08-05  2211607      74
#
#             type  club_id  player_id  \
# 0          Cards      610       4425
# 1          Cards      383      33210
# 2          Goals      383      36500
# 3          Goals      383      36500
# 4  Substitutions      383      36500
#
#                                          description  player_in_id  \
# 0               1. Yellow card  , Mass confrontation           NaN
# 1               1. Yellow card  , Mass confrontation           NaN
# 2  , Header, 1. Tournament Goal Assist: , Corner,...           NaN
# 3  , Right-footed shot, 2. Tournament Goal Assist...           NaN
# ...

# %%
df5['date'] = pd.to_datetime(df5['date'])

# %%
df_filtered_5 = df5[df5['date'] >= pd.to_datetime('2019-02-24')]
print(df_filtered_5)
# Out:
#                            game_event_id       date  game_id  minute  \
# 334595  f896e8e95eebcd7f75eec8604780035e 2019-03-12  3047691      50
# 334596  58f07132f4b59ef014f3ecc867652fa8 2019-03-12  3047691      76
# 334597  fdfca30ee098406613ee0d6a9514c060 2019-03-12  3047691      90
# 334598  18c3b79961e659da06615fdcc9c305e4 2019-03-12  3047691      71
# 334599  aeb2a612875bb6f8e8302dafbd8813a8 2019-03-12  3047691      83
# ...                                  ...        ...      ...     ...
# 687440  e10fd5f1cb2038d4e105e1d97ab14f72 2024-02-10  4279376      78
# 687441  959f200fb0ab3c110f4f5966d2b0f97f 2024-02-10  4279376      84
# 687442  a2126e824a1e0ee6c37aa7714190a138 2024-02-10  4279376      39
# 687443  f52b293d831a03bf8ed2f28af89dea8f 2024-02-10  4279376      78
# 687444  aed7337a7b5447e561e2bac3272632ea 2024-02-10  4279376      68
#
#                  type  club_id  player_id  \
# 334595          Goals      583      45320
# 334596  Substitutions      583      45320
# ...

# %%
df_filtered_5.shape
# Out:
# (315475, 10)

# %%
df_filtered_5.head()
# Out:
#                            game_event_id       date  game_id  minute  \
# 334595  f896e8e95eebcd7f75eec8604780035e 2019-03-12  3047691      50
# 334596  58f07132f4b59ef014f3ecc867652fa8 2019-03-12  3047691      76
# 334597  fdfca30ee098406613ee0d6a9514c060 2019-03-12  3047691      90
# 334598  18c3b79961e659da06615fdcc9c305e4 2019-03-12  3047691      71
# 334599  aeb2a612875bb6f8e8302dafbd8813a8 2019-03-12  3047691      83
#
#                  type  club_id  player_id  \
# 334595          Goals      583      45320
# 334596  Substitutions      583      45320
# 334597          Goals      583      45660
# 334598  Substitutions     2969     111036
# 334599  Substitutions     2969     111048
#
#                                        description  player_in_id  \
# 334595   , Direct free kick, 7. Goal of the Season           NaN
# 334596                                         NaN       45660.0
# 334597  , Right-footed shot, 2. Goal of the Season           NaN
# ...

# %%
df_filtered_5=df_filtered_5.drop(columns='player_assist_id')
df_filtered_5
# Out:
#                            game_event_id       date  game_id  minute  \
# 334595  f896e8e95eebcd7f75eec8604780035e 2019-03-12  3047691      50
# 334596  58f07132f4b59ef014f3ecc867652fa8 2019-03-12  3047691      76
# 334597  fdfca30ee098406613ee0d6a9514c060 2019-03-12  3047691      90
# 334598  18c3b79961e659da06615fdcc9c305e4 2019-03-12  3047691      71
# 334599  aeb2a612875bb6f8e8302dafbd8813a8 2019-03-12  3047691      83
# ...                                  ...        ...      ...     ...
# 687440  e10fd5f1cb2038d4e105e1d97ab14f72 2024-02-10  4279376      78
# 687441  959f200fb0ab3c110f4f5966d2b0f97f 2024-02-10  4279376      84
# 687442  a2126e824a1e0ee6c37aa7714190a138 2024-02-10  4279376      39
# 687443  f52b293d831a03bf8ed2f28af89dea8f 2024-02-10  4279376      78
# 687444  aed7337a7b5447e561e2bac3272632ea 2024-02-10  4279376      68
#
#                  type  club_id  player_id  \
# 334595          Goals      583      45320
# 334596  Substitutions      583      45320
# ...

# %%
df_filtered_5.isnull().sum()
# Out:
# game_event_id         0
# date                  0
# game_id               0
# minute                0
# type                  0
# club_id               0
# player_id             0
# description      184077
# player_in_id      99851
# dtype: int64

# %%
# import os
# desktop_path = os.path.expanduser('~') + '/Desktop'
# df_filtered_5.to_csv(os.path.join(desktop_path, 'game_events.csv'), index=False)

# %%
df6.shape
# Out:
# (2318953, 9)

# %%
df6['number'] = df6['number'].replace('-', 0)

# %%
df6.head()
# Out:
#                     game_lineups_id  game_id  club_id             type number  \
# 0  b2dbe01c3656b06c8e23e9de714e26bb  2317258      610      substitutes      5
# 1  b50a3ec6d52fd1490aab42042ac4f738  2317258      610  starting_lineup      4
# 2  7d890e6d0ff8af84b065839966a0ec81  2317258     1090      substitutes     11
# 3  8c355268678b9bbc7084221b1f0fde36  2317258      610  starting_lineup     17
# 4  76193074d549e5fdce4cdcbba0d66247  2317258     1090  starting_lineup     23
#
#    player_id        player_name  team_captain            position
# 0       1443  Christian Poulsen             0  Defensive Midfield
# 1       5017   Niklas Moisander             0         Centre-Back
# 2       9602    Maarten Martens             0         Left Winger
# 3      12282        Daley Blind             0           Left-Back
# 4      25427        Roy Beerens             0        Right Winger

# %%
# import os
# desktop_path = os.path.expanduser('~') + '/Desktop'
# df6.to_csv(os.path.join(desktop_path, 'game_lineups.csv'), index=False)

# %%
df7.shape
# Out:
# (66545, 23)

# %%
df7.head()
# Out:
#    game_id competition_id  season         round        date  home_club_id  \
# 0  2321044             L1    2013   2. Matchday  2013-08-18            16
# 1  2321060             L1    2013   3. Matchday  2013-08-25            23
# 2  2321086             L1    2013   6. Matchday  2013-09-21             4
# 3  2321152             L1    2013  11. Matchday  2013-11-02            44
# 4  2321205             L1    2013  17. Matchday  2013-12-21            41
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  ...  \
# 0            23                2                1                 1.0  ...
# 1            24                0                2                18.0  ...
# 2            16                1                1                15.0  ...
# 3            33                0                2                 7.0  ...
# 4            39                2                3                14.0  ...
#
#                  stadium attendance          referee  \
# ...

# %%
df7=df7.drop(columns='url')

# %%
df7.shape
# Out:
# (66545, 22)

# %%
df7.columns
# Out:
# Index(['game_id', 'competition_id', 'season', 'round', 'date', 'home_club_id',
#        'away_club_id', 'home_club_goals', 'away_club_goals',
#        'home_club_position', 'away_club_position', 'home_club_manager_name',
#        'away_club_manager_name', 'stadium', 'attendance', 'referee',
#        'home_club_formation', 'away_club_formation', 'home_club_name',
#        'away_club_name', 'aggregate', 'competition_type'],
#       dtype='object')

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66545 entries, 0 to 66544
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   game_id                 66545 non-null  int64
#  1   competition_id          66545 non-null  object
#  2   season                  66545 non-null  int64
#  3   round                   66545 non-null  object
#  4   date                    66545 non-null  object
#  5   home_club_id            66545 non-null  int64
#  6   away_club_id            66545 non-null  int64
#  7   home_club_goals         66545 non-null  int64
#  8   away_club_goals         66545 non-null  int64
#  9   home_club_position      46764 non-null  float64
#  10  away_club_position      46764 non-null  float64
#  11  home_club_manager_name  65802 non-null  object
#  12  away_club_manager_name  65802 non-null  object
#  13  stadium                 66332 non-null  object
# ...

# %%
# import os
# desktop_path = os.path.expanduser('~') + '/Desktop'
# df7.to_csv(os.path.join(desktop_path, 'games.csv'), index=False)

# %%
df8.shape
# Out:
# (465254, 5)

# %%
df8.head()
# Out:
#    player_id        date  market_value_in_eur  current_club_id  \
# 0     405973  2000-01-20               150000             3057
# 1     342216  2001-07-20               100000             1241
# 2       3132  2003-12-09               400000              126
# 3       6893  2003-12-15               900000              984
# 4         10  2004-10-04              7000000              398
#
#   player_club_domestic_competition_id
# 0                                 BE1
# 1                                 SC1
# 2                                 TR1
# 3                                 GB1
# 4                                 IT1

# %%
df8['date'] = pd.to_datetime(df8['date'])
df8 = df8[df8['date'] >= pd.to_datetime('2019-02-24')]

# %%
# import os
# desktop_path = os.path.expanduser('~') + '/Desktop'
# df8.to_csv(os.path.join(desktop_path, 'player_valuations.csv'), index=False)

# %%
df9.shape
# Out:
# (30484, 23)

# %%
df9.columns
# Out:
# Index(['player_id', 'first_name', 'last_name', 'name', 'last_season',
#        'current_club_id', 'player_code', 'country_of_birth', 'city_of_birth',
#        'country_of_citizenship', 'date_of_birth', 'sub_position', 'position',
#        'foot', 'height_in_cm', 'contract_expiration_date', 'agent_name',
#        'image_url', 'url', 'current_club_domestic_competition_id',
#        'current_club_name', 'market_value_in_eur',
#        'highest_market_value_in_eur'],
#       dtype='object')

# %%
df9=df9.drop(columns=['image_url','url'])

# %%
df9['contract_expiration_date'] = pd.to_datetime(df9['contract_expiration_date'])

# %%
df9.shape
# Out:
# (30484, 21)

# %%
df9.columns
# Out:
# Index(['player_id', 'first_name', 'last_name', 'name', 'last_season',
#        'current_club_id', 'player_code', 'country_of_birth', 'city_of_birth',
#        'country_of_citizenship', 'date_of_birth', 'sub_position', 'position',
#        'foot', 'height_in_cm', 'contract_expiration_date', 'agent_name',
#        'current_club_domestic_competition_id', 'current_club_name',
#        'market_value_in_eur', 'highest_market_value_in_eur'],
#       dtype='object')

# %%
df9.iloc[:, 10:20].head()
# Out:
#   date_of_birth    sub_position    position   foot  height_in_cm  \
# 0    1978-06-09  Centre-Forward      Attack  right         184.0
# 1    1980-08-06      Goalkeeper  Goalkeeper   left         190.0
# 2    1981-01-30  Centre-Forward      Attack    NaN           NaN
# 3    1978-05-08     Centre-Back    Defender    NaN           NaN
# 4    1981-03-18      Goalkeeper  Goalkeeper  right         194.0
#
#   contract_expiration_date            agent_name  \
# 0                      NaT  ASBW Sport Marketing
# 1                      NaT      Neubauer 13 GmbH
# 2                      NaT       CSKA-AS-23 Ltd.
# 3                      NaT                   NaN
# 4                      NaT                   IFM
#
#   current_club_domestic_competition_id  \
# 0                                  IT1
# 1                                   L1
# 2                                  GR1
# 3                                  IT1
# 4                                   L1
#
# ...

# %%
df9['contract_expiration_date'].isnull().sum()
# Out:
# 11465

# %% [markdown]
# df9.iloc[:, 10:20].head()

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30484 entries, 0 to 30483
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             30484 non-null  int64
#  1   first_name                            28492 non-null  object
#  2   last_name                             30484 non-null  object
#  3   name                                  30484 non-null  object
#  4   last_season                           30484 non-null  int64
#  5   current_club_id                       30484 non-null  int64
#  6   player_code                           30484 non-null  object
#  7   country_of_birth                      27767 non-null  object
#  8   city_of_birth                         28284 non-null  object
#  9   country_of_citizenship                29911 non-null  object
#  10  date_of_birth                         30439 non-null  object
# ...

# %%
# import os
# desktop_path = os.path.expanduser('~') + '/Desktop'
# df9.to_csv(os.path.join(desktop_path, 'players.csv'), index=False)

# %%
df_filtered_4.columns
# Out:
# Index(['competition_id', 'competition_code', 'name', 'sub_type', 'type',
#        'country_id', 'country_name', 'domestic_league_code'],
#       dtype='object')

# %%
df_filtered_4.head()
# Out:
#   competition_id               competition_code  \
# 0            CIT                      italy-cup
# 1           NLSC           johan-cruijff-schaal
# 2            GRP                kypello-elladas
# 3           POSU  supertaca-candido-de-oliveira
# 4           RUSS              russian-super-cup
#
#                             name            sub_type          type  \
# 0                      italy-cup        domestic_cup  domestic_cup
# 1           johan-cruijff-schaal  domestic_super_cup         other
# 2                kypello-elladas        domestic_cup  domestic_cup
# 3  supertaca-candido-de-oliveira  domestic_super_cup         other
# 4              russian-super-cup  domestic_super_cup         other
#
#    country_id country_name domestic_league_code
# 0          75        Italy                  IT1
# 1         122  Netherlands                  NL1
# 2          56       Greece                  GR1
# 3         136     Portugal                  PO1
# ...

# %%
df_filtered.head()
# Out:
#          appearance_id  game_id  player_id  player_club_id  \
# 871717  3047774_131996  3047774     131996            1041
# 871718  3047774_137745  3047774     137745            1041
# 871719  3047774_161869  3047774     161869             162
# 871720  3047774_167850  3047774     167850            1041
# 871721  3047774_174694  3047774     174694             162
#
#         player_current_club_id       date      player_name competition_id  \
# 871717                    1050 2019-02-24  Bertrand Traoré            FR1
# 871718                     543 2019-02-24           Marçal            FR1
# 871719                    2441 2019-02-24   Djibril Sidibé            FR1
# 871720                      13 2019-02-24    Memphis Depay            FR1
# 871721                    1075 2019-02-24       Rony Lopes            FR1
#
#         yellow_cards  red_cards  goals  assists  minutes_played
# 871717             0          0      0        0              90
# ...

# %%
df_filtered.columns
# Out:
# Index(['appearance_id', 'game_id', 'player_id', 'player_club_id',
#        'player_current_club_id', 'date', 'player_name', 'competition_id',
#        'yellow_cards', 'red_cards', 'goals', 'assists', 'minutes_played'],
#       dtype='object')

# %%
df6.isnull().sum()
# Out:
# game_lineups_id    0
# game_id            0
# club_id            0
# type               0
# number             0
# player_id          0
# player_name        0
# team_captain       0
# position           3
# dtype: int64

# %%
df_filtered_4['type'].unique()
# Out:
# array(['domestic_cup', 'other', 'domestic_league', 'international_cup'],
#       dtype=object)

# %%
df6['number'].unique()
# Out:
# array(['5', '4', '11', '17', '23', '29', '1', '20', '12', '16', '3', '10',
#        '9', '8', '15', '27', '7', '24', '40', '25', '19', '2', '26', '28',
#        '22', '21', '31', '39', '13', '14', '6', '-', '30', '18', '37',
#        '34', '38', '33', '32', '35', '58', '36', '41', '44', '50', '42',
#        '99', '88', '80', '49', '51', '72', '84', '89', '55', '70', '77',
#        '73', '45', '87', '92', '64', '91', '90', '47', '76', '68', '71',
#        '61', '75', '78', '95', '85', '69', '93', '46', '59', '83', '66',
#        '56', '98', '62', '48', '57', '82', '67', '43', '63', '79', '54',
#        '53', '94', '52', '60', '65', '81', '74', '97', '96', '86', '880',
#        '189', '203', 1, 97, 15, 5, 37, 14, 21, 8, 11, 10, 99, 7, 26, 28,
#        2, 4, 17, 23, 32, 9, 27, 3, 29, 22, 33, 16, 19, 94, 36, 18, 62, 30,
#        45, 6, 34, 93, 66, 39, 38, 55, 24, 13, 95, 12, 44, 80, 47, 20, 25,
#        96, 88, 41, 67, 31, 40, 77, 35, 43, 50, 72, 42, 98, 75, 91, 56, 70,
# ...
